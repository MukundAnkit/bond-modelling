# %% [markdown]
# # Module 1: Single Instrument Pricing — Verification
#
# Verify engine output against known textbook examples before advancing to Module 2.

# %%
import sys

sys.path.insert(0, "..")

from src.module1_pricing.bond import Bond
from src.module1_pricing.pricing import price
from src.module1_pricing.ytm_solver import ytm_solver

# %% [markdown]
# ### Example 1: Par Bond
# A 3-year 5% semi-annual bond yielding 5% should trade at par (100).

# %%
b = Bond(100, 0.05, 3.0, 2)
p = price(b, 0.05)
y = ytm_solver(b, p)
print(f"Price: {p:.6f}  (expected 100.0)")
print(f"YTM:   {y * 100:.4f}%  (expected 5.0%)")

# %% [markdown]
# ### Example 2: Premium Bond
# A 3-year 5% semi-annual bond yielding 4% should trade at ~102.80.

# %%
p = price(b, 0.04)
y = ytm_solver(b, p)
print(f"Price: {p:.6f}  (expected ~102.80)")
print(f"YTM:   {y * 100:.4f}%  (expected 4.0%)")

# %% [markdown]
# ### Example 3: Discount Bond
# A 3-year 5% semi-annual bond yielding 6% should trade at ~97.29.

# %%
p = price(b, 0.06)
y = ytm_solver(b, p)
print(f"Price: {p:.6f}  (expected ~97.29)")
print(f"YTM:   {y * 100:.4f}%  (expected 6.0%)")

# %% [markdown]
# ### Example 4: Zero-Coupon Bond
# A 5-year zero-coupon bond (face 100) yielding 3% should price at PV = 100 / 1.03^5 ≈ 86.26.

# %%
zcb = Bond(100, 0.0, 5.0, 1)
p = price(zcb, 0.03)
y = ytm_solver(zcb, p)
print(f"Price: {p:.6f}  (expected {100 / 1.03**5:.6f})")
print(f"YTM:   {y * 100:.4f}%  (expected 3.0%)")
